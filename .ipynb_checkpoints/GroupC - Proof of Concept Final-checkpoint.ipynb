# %%
import requests 
from bs4 import BeautifulSoup

# %%
search

url = 'https://www.ebay.com/sch/i.html?_from=R40&_trksid=p2334524.m570.l1313&_nkw=mac+miller+vinyl+records&_sacat=0&LH_TitleDesc=0&_odkw=vinyl+records&_osacat=0'
page = requests.get(url)
print(type(page))
print(page)
# Out:
# <class 'requests.models.Response'>
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
tables = soup.find(class_ = "s-item s-item__pl-on-bottom s-item--watch-at-corner").text
print(tables)
# Out:
# Mac Miller - KIDS (New Vinyl LP Sealed!) The Landmark 2010 Mixtape!Brand New5.0 out of 5 stars.6 product ratings - Mac Miller - KIDS (New Vinyl LP Sealed!) The Landmark 2010 Mixtape!$40.00Buy It NowFree shippingAlmost gone37 sold T⁣S⁣p⁣G⁣	⁣9⁣V⁣o⁣	⁣n⁣s⁣S⁣o⁣A⁣	⁣r⁣e⁣d⁣1⁣F⁣⁣	⁣⁣K⁣⁣⁣⁣1⁣

# %%
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
tables = soup.find_all("table")
ratesTable = tables[0]
print(ratesTable.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 9]><html class="ie9 srp-ds6" lang="en"><![endif]-->
# <!--[if gt IE 9]><!-->
# <html class="srp-ds6" lang="en">
#  <!--<![endif]-->
#  <!--M#s0-1-->
#  <noscript class="x-page-config" id="s0-1">
#  </noscript>
#  <!--M/-->
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script>
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

item_name = []
prices = []



r = requests.get("https://www.ebay.com/sch/i.html?_from=R40&_trksid=p2334524.m570.l1313&_nkw=mac+miller+vinyl+records&_sacat=0&LH_TitleDesc=0&_odkw=vinyl+records&_osacat=0")
data= r.text
soup = BeautifulSoup(data)
listings = soup.find_all('li', {'class':'s-item'})
#print(listings)

for listing in listings:
    prod_name = ' '
    prod_price = ' '
    for name in listing.find_all('h3', {'class': 's-item__title'}):
        if(str(name.find(text = True, recursive = False)) != 'None'):
            prod_name = str(name.find(text = True, recursive = False))
            item_name.append(prod_name)
    if(prod_name!=" "):
        price = listing.find('span', attrs={'class':"s-item__price"})
        prod_price = str(price.find(text=True, recursive=False))
        prices.append(prod_price)

print(item_name, '\n')
#print(len(item_name))
print(prices)
#print(len(prices))
# Out:
# ['Shop on eBay', 'Mac Miller - KIDS (New Vinyl LP Sealed!) The Landmark 2010 Mixtape!', 'Mac Miller Vinyl Macadelic 10th Anniversary Edition Tri Colored LP! SOLD OUT!', 'Circles 2LP Clear Vinyl With Poster by Mac Miller [Vinyl] (wmvlp4905592)', 'Mac Miller Best Day Ever 2x LP Purple Pink & Red Colored Vinyl Sealed in Hand!', 'Mac Miller - Macadelic 10th Anniversary Vinyl Poster Tri Embossed Cover IN-HAND', 'MAC MILLER - CIRCLES - NEW SEALED VINYL LP', 'Mac Miller - Macadelic Vinyl 10th Anniversary Edition Tri Colored LP Exclusive', 'Mac Miller - GOOD AM - Silver Colored Vinyl LP Urban Outfitters NEW & SEALED!!', 'Mac Miller The Divine Feminine Album Limited 2XLP Pink Vinyl Record. UO-Limited!', 'Mac Miller KIDS Black Vinyl', 'Mac Miller Best Day Ever Vinyl LP Purple Pink Red Swirl Urban Outfitters IN HAND', 'Mac Miller - Macadelic Vinyl 10th Anniversary Edition Tri Colored LP IN HAND', 'Mac Miller VINYL Macadelic 10th Anniversary Edition Tri Colored LP Vinyl IN HAND', 'MAC MILLER - C
# ...

# %%
df = pd.DataFrame({"Item Listing":item_name, "Price":prices})
df.drop(labels=0, axis=0, inplace=False)
# Out:
#                                          Item Listing    Price
# 1   Mac Miller - KIDS (New Vinyl LP Sealed!) The L...   $40.00
# 2   Mac Miller Vinyl Macadelic 10th Anniversary Ed...   $99.99
# 3   Circles 2LP Clear Vinyl With Poster by Mac Mil...   $40.27
# 4   Mac Miller Best Day Ever 2x LP Purple Pink & R...   $57.99
# 5   Mac Miller - Macadelic 10th Anniversary Vinyl ...   $82.00
# ..                                                ...      ...
# 71  Mac Miller Circles Limited Edition White Color...  $100.00
# 72  Mac Miller - K.I.D.S. (2-LP) Limited Edition R...   $79.95
# 73  Mac Miller – Best Day Ever - 2 LP Vinyl Record...   $49.99
# 74  Mac Miller Vinyl Macadelic 10th Anniversary Ed...   $99.99
# 75  Mac Miller VINYL Macadelic 10th Anniversary Ed...   $99.95
#
# [75 rows x 2 columns]

# %%
#Look For Price = None
NoPrice = df.loc[df['Price'].str.contains("None", case=False)]
NoPrice
# Out:
#                                          Item Listing Price
# 60  Mac Miller - Watching Movies With The Sound Of...  None

# %%
df['Price'] = [x.strip('$') for x in df['Price']]
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')
df
# Out:
#                                          Item Listing   Price
# 0                                        Shop on eBay   20.00
# 1   Mac Miller - KIDS (New Vinyl LP Sealed!) The L...   40.00
# 2   Mac Miller Vinyl Macadelic 10th Anniversary Ed...   99.99
# 3   Circles 2LP Clear Vinyl With Poster by Mac Mil...   40.27
# 4   Mac Miller Best Day Ever 2x LP Purple Pink & R...   57.99
# ..                                                ...     ...
# 71  Mac Miller Circles Limited Edition White Color...  100.00
# 72  Mac Miller - K.I.D.S. (2-LP) Limited Edition R...   79.95
# 73  Mac Miller – Best Day Ever - 2 LP Vinyl Record...   49.99
# 74  Mac Miller Vinyl Macadelic 10th Anniversary Ed...   99.99
# 75  Mac Miller VINYL Macadelic 10th Anniversary Ed...   99.95
#
# [76 rows x 2 columns]

# %%
df1 = df.sort_index()
df1.plot();
